# %%
#1.Find the error in the following Python code:
#import math
#print(Math.sqrt(16))
#Answer: Math should be started with lower case like math
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
#2.Find the error in the following Python code:
""" def my_function():
    x += 5
    print(x)

x = 10
my_function() """
#Answer: x is not declared globally
def my_function():
    global x
    x += 5
    print(x)

x = 10
my_function()
# Out:
# 15

# %%
#3.x = 5
""" if x = 10:
    print("x is 10") """
#Answer: assignment operator code is commented and comparision operator should be ==
x=5
if x == 10:
    print("x is 10")

# %%
#4.
""" numbers = [5, 3, 8, 2]
print(numbers.sort()) """
#Answer: sort() modifies the list in place and it will return none
numbers = [5, 3, 8, 2]
numbers.sort()
print(numbers)
# Out:
# [2, 3, 5, 8]

# %%
#5.
"""def square(n):
    n * n

print(square(4)) """
#Answer: return statement is missing
def square(n):
    return n * n
    

print(square(4))
# Out:
# 16

# %%
#6.
""" my_tuple = (1, 2, 3)
my_tuple[1] = 5 """
#Answer: Tuple is immutable
# Out:
# ' my_tuple = (1, 2, 3)\nmy_tuple[1] = 5 '

# %%
#7.
""" name = "Alice"
age = 25
print("My name is %s and I am %d years old" % (name)) """
#Answer: format error, age argument is missing.
name = "Alice"
age = 25
print("My name is %s and I am %d years old" % (name,age))
# Out:
# My name is Alice and I am 25 years old

# %%
#8.
"""a = [1, 2, 3]
b = [1, 2, 3]
if a is b:
    print("Lists are equal") """
#Answer: condition is comparing the objects and not value
a = [1, 2, 3]
b = [1, 2, 3]
if a == b:
    print("Lists are equal")
# Out:
# Lists are equal

# %%
#9.
""" for i in range(5, 1):
    print(i) """
#Answer: Stepping value is missing it should be in negative value because starting value is higher than end value
for i in range(5, 1,-1):
    print(i)
# Out:
# 5
# 4
# 3
# 2

# %%
#10.
""" student = {"name": "John", "age": 20}
print(student[name]) """
#Answer: Key is string and it should be in double quotes.
student = {"name": "John", "age": 20}
print(student["name"])
# Out:
# John
