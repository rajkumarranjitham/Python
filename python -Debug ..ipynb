# %%
#1.Find the error in the following Python code:

# for i in range(5)
#    print(i)
#Answer: Coloon is missing
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#2.What will be the output of this code?

a = 10
b = "5"
#print(a + b)
#Answer: Type error
print(a,b)
# Out:
# 10 5

# %%
#3.What is the issue in this Python snippet?

# def add_numbers(a, b)
#    return a + b
#Answer: colon is missing
def add_numbers(a, b):
    return a + b

# %%
#4.Identify the bug in the following Python code:

 numbers = [1, 2, 3, 4]
print(numbers[4])
#Answer: out of range @ index=4

# %%
#5.Find the error in the following Python code:
#print "Hello, World!"
#Answer:
print("Hello, World!")
# Out:
# Hello, World!

# %%
#6.Find the error in the following Python code:
x = 5 / 0
#Answer: Division error

# %%
#7.Find the error in the following Python code:name = "Alice"
age = 25
print("Name: " + name + ", Age: " + age)
#Answer: Name is not defined

# %%
#8.Find the error
for i in range(1, 10, -1):
    print(i)
#Answer: Negative steps of third argument

# %%
#9. Find the error in the following Python code:
x = 10
if x = 5:
    print("x is 5")
#Answer: if x==5:
x = 10
if x == 5:
    print("x is 5")

# %%
#10. Identify the error in the following function definition:

def greet(name)
    print("Hello, " + name)
#Answer: Colon is missing
def greet(name):
    print("Hello, " + name)
